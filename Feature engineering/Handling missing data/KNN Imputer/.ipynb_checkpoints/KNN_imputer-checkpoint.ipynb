# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.impute import KNNImputer,SimpleImputer
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv('train.csv',usecols=['Age','Pclass','Fare','Survived'])

# %%
df.head()
# Out:
#    Survived  Pclass   Age     Fare
# 0         0       3  22.0   7.2500
# 1         1       1  38.0  71.2833
# 2         1       3  26.0   7.9250
# 3         1       1  35.0  53.1000
# 4         0       3  35.0   8.0500

# %%
df.isnull().mean()*100
# Out:
# Survived     0.00000
# Pclass       0.00000
# Age         19.86532
# Fare         0.00000
# dtype: float64

# %%
X=df.drop(columns=['Survived'])
y=df['Survived']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.head()
# Out:
#      Pclass   Age     Fare
# 30        1  40.0  27.7208
# 10        3   4.0  16.7000
# 873       3  47.0   9.0000
# 182       3   9.0  31.3875
# 876       3  20.0   9.8458

# %%
knn=KNNImputer()

X_train_trf=knn.fit_transform(X_train)
X_test_trf=knn.transform(X_test)

# %% [raw]
# we can also change neigbours from n_neighbour parameter and then check the accuracy if it improves. by default the number of neighbours is 5

# %%
In KNN Imputer, the distance parameter controls how similarity between rows is measured.
Since KNN is distance-based, this choice directly affects which neighbors are selected and how accurate the imputation is.

1. Distance parameter in sklearn.KNNImputer
KNNImputer(
    n_neighbors=5,
    weights="uniform",
    metric="nan_euclidean"
)


🔹 The distance parameter is metric
🔹 Default value: "nan_euclidean"

2. Default distance: nan_euclidean ⭐
What it does

Computes Euclidean distance

Ignores NaN values

Normalizes distance based on number of valid features

Formula
𝑑
(
𝑥
,
𝑦
)
=
𝑛
𝑚
∑
𝑖
∈
valid
(
𝑥
𝑖
−
𝑦
𝑖
)
2
d(x,y)=
m
n
	​

i∈valid
∑
	​

(x
i
	​

−y
i
	​

)
2
	​


Where:

𝑛
n = total features

𝑚
m = features without NaN in both rows

Why it is the default

✔ Works with missing values
✔ Fair comparison even when features differ
✔ Prevents rows with many NaNs from appearing closer

3. Why normal Euclidean distance is NOT used
Standard Euclidean distance
𝑑
=
∑
(
𝑥
𝑖
−
𝑦
𝑖
)
2
d=
∑(x
i
	​

−y
i
	​

)
2
	​


❌ Fails if any feature is NaN
❌ No normalization → biased distances

👉 Hence, cannot be default

4. Can we change the distance metric?
❌ In KNNImputer

Only nan_euclidean is officially supported

You cannot directly use:

Manhattan

Minkowski

Cosine

✅ Alternative

Use sklearn.impute.IterativeImputer or

Custom KNN implementation

5. Distance vs Weights (important distinction)
Parameter	Role
metric	How distance is computed
weights	How neighbors influence imputation
weights options:

"uniform" (default) → all neighbors equal

"distance" → closer neighbors have more influence

⚠️ Distance metric ≠ weights

6. Comparison: Default vs Hypothetical Alternatives
Metric	Works with NaN	Normalized	Used in KNNImputer
Euclidean	❌ No	❌ No	❌
Manhattan	❌ No	❌ No	❌
Cosine	❌ No	❌ No	❌
nan_euclidean	✅ Yes	✅ Yes	✅ Default
7. Practical Example
Data
A	B	C
2	NaN	4
3	6	NaN

Valid feature: A only

Total features = 3

Normalized distance:

𝑑
=
3
1
(
2
−
3
)
2
=
3
d=
1
3
	​

(2−3)
2
	​

=
3
	​


Without normalization → distance = 1 (misleading)

8. When default distance is BEST

✔ Mixed missing patterns
✔ Numerical features
✔ Real-world datasets
✔ Fair neighbor selection needed

9. Exam-ready one-liners

Distance parameter in KNN Imputer: metric

Default metric: nan_euclidean

Why default: Handles missing values and normalizes distance

Key advantage: Prevents bias due to unequal feature availability

Final takeaway

KNN Imputer uses nan_euclidean distance by default because it ignores missing values and rescales distances for fair neighbor selection—something standard Euclidean distance cannot do.

# %%
X_train_trf
# Out:
# array([[  1.    ,  40.    ,  27.7208],
#        [  3.    ,   4.    ,  16.7   ],
#        [  3.    ,  47.    ,   9.    ],
#        ...,
#        [  1.    ,  71.    ,  49.5042],
#        [  1.    ,  28.    , 221.7792],
#        [  1.    ,  42.8   ,  25.925 ]], shape=(712, 3))

# %% [raw]
# this is a numpy array, so we need to convert it to pandas dataframe

# %%
pd.DataFrame(X_train_trf,columns=X_train.columns)
# Out:
#      Pclass   Age      Fare
# 0       1.0  40.0   27.7208
# 1       3.0   4.0   16.7000
# 2       3.0  47.0    9.0000
# 3       3.0   9.0   31.3875
# 4       3.0  20.0    9.8458
# ..      ...   ...       ...
# 707     3.0  30.0    8.6625
# 708     3.0  24.2    8.7125
# 709     1.0  71.0   49.5042
# 710     1.0  28.0  221.7792
# 711     1.0  42.8   25.9250
#
# [712 rows x 3 columns]

# %%
lr=LogisticRegression()
lr.fit(X_train_trf,y_train)
y_pred=lr.predict(X_test_trf)
accuracy_score(y_test,y_pred)
# Out:
# 0.7039106145251397

# %%
# comparisson with Simple Imputer -->mean
si=SimpleImputer()
X_train_trf2=si.fit_transform(X_train)
X_test_trf2=si.transform(X_test)

# %%
lr=LogisticRegression()
lr.fit(X_train_trf2,y_train)
y_pred=lr.predict(X_test_trf2)
accuracy_score(y_test,y_pred)
# Out:
# 0.6927374301675978

# %% [raw]
# KNN imputer gives a better result here
